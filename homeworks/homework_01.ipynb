# %% [markdown]
# ### **Домашняя работа 1**
#
# #### **Практическая часть**
#
# - Обучите нейронную сеть бинарной классификации XOR датасета.
#
# - При обучении постройте графики функций потерь и точности классификации на обучающих и валидационных данных.
#
# - Сохраните обученную модель и протестируйте ее качество на тестовых данных.
#
# #### **Теоретическая часть**
#
# - Что вычисляет алгоритм обратного распространения ошибки (backpropagation)?
#   Как backpropagation используется при обучении нейронных сетей?
#
# - В чем отличие параметров от гиперпараметров при обучении нейронной сети?
#
# - Зачем данные делить на данные для обучения, валидации и тестирования?
#
# - Что такое задача регрессии? Чем задача регрессии отличается от задачи классификации? Напишите формулы функции потерь и метрики качества для задачи регрессии.
#
# - Постановка задачи бинарной классификации. Функция потерь  бинарной классификации. Какие вы знаете метрики качества задачи бинарной классификации?
#
# - Gradient Descent (GD), Stochastic Gradient Descent (SGD) и Batch Stochastic Gradient Descent (Batch SGD). В чем их различия, плюсы и минусы каждого?
#
# - Если бы мы имели бесконечные ресурсы (память, GPU, CPU и т.д.), а также нам была бы не важна скорость сходимости модели, то какой метод GD, SGD или Batch SGD лучше использовать?
#
# - При увеличении размера батча, следует уменьшать или увеличивать темп обучения (learning rate)? Почему?
