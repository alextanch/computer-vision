# %% [markdown]
# #### **Домашняя работа 1**
#
# ##### **Теоретическая часть**
#
# - Для чего используется алгоритм обратного распространения ошибки (backpropagation)?
#   Как backpropagation используется при обучении нейронных сетей?
#
# - Что такое параметры и гиперпараметры нейронной сети?
#
# - Зачем данные делить на данные для обучения, валидации и тестирования.
#
# - Что такое задача регрессии в машинном обучении? Напишите формулы функции потерь и метрики качества для задачи регрессии.
#
# - Gradient Descent (GD), Stochastic Gradient Descent (SGD) и Batch Stochastic Gradient Descent (Batch SGD).
#   В чем их различия, плюсы и минусы каждого?
#
# - Если бы мы имели бесконечные ресурсы (память, GPU, CPU и т.д.), а также нам была бы не важна скорость сходимости модели, то какой метод GD, SGD или Batch SGD лучше использовать?
#
# - При увеличении размера батча следует уменьшать или увеличивать learning rate? Почему?
#
# ##### **Практическая часть**
#
# - Обучите нейронную сеть решать следующую задачу регрессии:
#
#   необходимо приблизить значения функции
#   $$
#     y=\sin x + \varepsilon\,,\qquad
#     x\in[-\pi,\pi]\,,\qquad
#     \varepsilon\sim\mathcal{N}(0,\sigma^2)
#   $$
#   полиномом третьей степени:
#   $$
#     y = a + b x + c x^2 + d x^3
#   $$
#
# - Сохраните обученную модель и протестируйте ее качество на тестовых данных.
