# %% [markdown]
# ### **Домашняя работа 2**
#
# #### **Практическая часть**
#
# - Скачайте и разархивируйте CIFAR-10 датасет:
#
#   ```python
#     from src.utils import download_and_extract
#
#     download_and_extract("1ukaybJdXlnH7eyIl_7vpSXRdU5nMVDx9", "cifar-10.zip", DATA_DIR)
#   ```
#
# - Обучите нейронную полносвязную сеть классифицировать изображения из датасета CIFAR-10.
#
# - Подберите подходящую архитектуру сети и методы регуляризации.
#
# - Протестируйте обученную модель сети на тестовых данных. Сохраните на диск тестовые изображения на которых сеть ошиблась.
#
# #### **Теоретическая часть**
#
# - Приведите пример небольшой полносвязной сети и объясните, как происходят вычисления слоев сети.
#
# - Сколько обучаемых параметров будет в полносвязной сети с входным слоем размера 2, двумя скрытыми слоями размера 10 и 5, и выходным слоем размера 1?
#
# - Опишите как работает Dropout в режиме обучения и в режиме инференса. Для чего применяется Dropout?
#
# - Какие недостатки применения полносвязных сетей для обработки изображений?
#
# - Для чего применяется регуляризация при обучении нейронных сетей? Какие методы регуляризации вы знаете?
