# %% [markdown]
# ### **Контактная информация**
#
# - **Александр Танченко**
#
# - Ведущий инженер-программист
#
# - Лаборатория интеллектуальных беспилотных систем, НИУ ВШЭ
#
# - mail: alex.tanch@gmail.com
#
# - telegram: alextanch
#
# - github: alextanch
#
# **Прислать на почту alex.tanch@gmail.com:**
#
# - ФИО
#
# - курс
#
# - программа обучения
#
# - telegram username
#
# - github username

# %% [markdown]
# ### **Курс: "Глубокое обучение в задачах компьютерного зрения"**
#
# Курс будет читаться в 3 и 4 модуле.

# %% [markdown]
# #### **Модуль 3**
#
# **10 занятий с 20 января по 24 марта**
#
# **План занятий**
#
# *Архитектуры нейронных сетей:*
#
# 1. Основы PyTorch. Обучение нейронных сетей.
#
# 2. Полносвязные нейронные сети. Методы регуляризации.
# 3. Сверточные нейронные сети. Классические архитектуры.
# 4. Остаточные сети (residual networks). Современные архитектуры.
# 5. Визуальные трансформеры.
#
# *Примеры применения нейронных сетей к задачам компьютерного зрения:*
#
# 6. Обучение с малым количеством примеров (few-shot learning).
#
# 7. Cамообучение (self-supervised learning).
# 8. Классификация изображений.
# 9. Сегментация изображений.
#
# *Последнее занятие модуля:*
#
# 10. Прием домашних заданий. Оценка за модуль.

# %% [markdown]
# #### **Оценка за модуль**
#
# - Баллы начисляются за домашние работы (ДР).
#
# - Чтобы сдать ДP, необходимо получить **pull request approve** и пройти **собеседование**.
# - За ДP, сданное в течении 2-х недель можно получить максимум 2 балла, если сдали после двух недель - 1 балл.
#
# - Собеседования будут проходить в конце занятий.
# - На собеседовании нужно объяснить ваше решение ДP и ответить на вопросы по теории.
# - Пример вычисления оценки за модуль:

# %%
# число домашних работ в модуле
N = 9 

# сумма баллов за домашние работы
X = 0 + 1 + 2 + 0 + 1 + 2 + 0 + 1 + 2 

# оценка за модуль
score = int(10 * X / (2 * N) + 0.5)

print(f"Оценка за модуль: {score}")

# %% [markdown]
# #### **GitHub репозиторий курса**
#
# - Репозиторий курса
#
#     https://github.com/alextanch/computer-vision
#
# - Структура репозитория:
#
#     ```bash
#         computer-vision
#             │
#             ├── notebooks                 - ноутбуки занятий
#             │     ├── notebook_01.ipynb
#             │     ├── notebook_02.ipynb
#             │     ├──...
#             │
#             ├── homeworks                 - домашние работы
#             │     ├── homework_01.ipynb
#             │     ├── homework_02.ipynb
#             │     ├──...
#             │
#             └── src                       - python скрипты
#     ```
#
# - Для запуска ноутбуков и домашних работ в Google Colab:
#     - скопируйте `computer-vision/homeworks` и `computer-vision/notebooks` в
#
#       https://drive.google.com/drive/my-drive/computer-vision
#
#     - откройте ноутбук и выберете runtime type
#
# - Для локального запуска:
#
#     - в Linux и MacOS, установите окружение:
#     ```bash
#         bash setup.sh
#     ```
#
#     - в ноутбуке выберете python kernel:
#     ```bash
#         .venv/bin/python
#     ```

# %% [markdown]
# #### **Выполнение домашних работ:**
#
# Например, для **A**lex **T**anchenko все ветки, коммиты и pull requests должны иметь префикс **at**:
#
# - В репозитории курса создадим ветку `at/hw` для всех ДР.
#
#   Эту ветку надо **создать один раз и никогда не удалять**. Она будет использоваться для создания pull request:
#
#   ```bash
#     git clone git@github.com:alextanch/computer-vision.git
#     cd computer-vision
#
#     git switch -c at/hw
#     git push -u origin at/hw
#   ```
#
# Например, для **ДР-1**:
#
# - В ветке `at/hw1` создадим файл `homeworks/homework_01.ipynb`:
#   ```bash
#     # обновим main c последними изменениями
#     git switch main
#     git pull origin main
#
#     git switch -c at/hw1
#
#     touch homeworks/homework_01.ipynb
#
#     git add homeworks/homework_01.ipynb
#     git commit -m "at: add homework_01.ipynb"
#
#     git push origin at/hw1
#   ```
#
# - Создадим **Draft pull request** с именем **at/hw1** из ветки **at/hw1** в ветку **at/hw**. При создании pull request:
#
#   - добавим себя - в **Assignees**
#
#   - в **Labels** выберем **homework**
#
#   - в **Projects** выберем **computer-vision**
#
#   - в **Milestone** выберем **Lesson 3 (Feb 3)** (soft deadline для ДР-1)
#
# - Пушим изменения в ветку `at/hw1`:
#   ```bash
#     git add homeworks/homework_01.ipynb
#     git commit -m "at: fix typo"
#     git push origin at/hw1
#   ```
#
# - Когда pull request готов к review:
#   - добавим **alextanch** в **Reviewers**
#
#   - нажмем кнопку **Ready for review**
#
# - после **code review**, получим **approve** и 👍
#
# - после approve, в pull request, нажмем **Squash and merge** и удалим ветку **at/hw1**
#
# - получим баллы на собеседовании 😊
#
# - переходим к следующему ДР и повторяем процесс 😳
#
# **Важно!**
#
# - Ноутбуки с ДР должны корректно запускаться как в google colab так и локально.
#
# - Перед коммитом ноутбука всегда делайте **Clear All Outputs**.
#
# - Меняйте статус вашего PR на kanban доске https://github.com/users/alextanch/projects/9/views/2
