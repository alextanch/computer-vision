# %% [markdown]
# ### **Контактная информация**
#
# - **Александр Танченко**
#
# - к.ф.м.н., вычислительная и математическая физика
#
# - ведущий инженер-программист
#
# - Лаборатория интеллектуальных беспилотных систем, НИУ ВШЭ
#
# - mail: alex.tanch@gmail.com
#
# - telegram: **@alextanch**
#
# - github: **alextanch**
#
# **Прислать на почту alex.tanch@gmail.com** или в **@alextanch**
#
# - ФИО
#
# - курс
#
# - программа обучения
#
# - telegram username
#
# - github username

# %% [markdown]
# ### **Курс: "Глубокое обучение в задачах компьютерного зрения"**
#
# Курс будет читаться в 3 и 4 модуле.

# %% [markdown]
# #### **Модуль 3**
#
# **9 занятий с 20 января по 24 марта**
#
# 1. PyTorch Basics. Neural Network Training.
#
# 2. Fully connected neural networks. Regularization methods.
#
# 3. Convolutional neural networks. Classical architectures.
#
# 4. Residual networks. Modern architectures.
#
# 5. Visual transformers.
#
# 6. Self-Supervised Learning.
#
# 7. Meta-Learning (Learning to Learn).
#
#     ~~Autoregressive Image Modeling.~~
#
# 8. Acelerate Model Training.
#
# 9. *Hard Deadline.*

# %% [markdown]
# #### **Модуль 4**
#
# **11 занятий с 1 апреля по 19 июня**
#
# 1. Object detection.
#
# 2. Image segmentation.
#
# 3. Deep Autoencoders.
#
# 4. Generative Adversarial Networks (GANs).
#
# 5. Normalizing Flows for image modeling.
#
# 6. Diffusion models.
#
# 7. Contrastive Language-Image Pre-training model (CLIP).
#
# 8. Segment Anything Model (SAM).
#
# 9. Stable diffusion.
#
# 10. Deploy models using ONNX, TensorRT and Triton.
#
# 11. *Hard Deadline.*

# %% [markdown]
# #### **Оценка за курс**
#
# - За домашние работы (ДР) начисляются баллы.
#
# - За каждую ДР можно получить максимум 2 балла.
#
# - **Soft Deadline** - две недели, **Hard Deadline** - последнее занятие в модуле.
#
# - После Soft Deadline можно получить максимум 1 балл за ДР.
#
# - Чтобы сдать ДP, надо получить **pull request approve** и пройти **собеседование**.
#
# - Собеседования будут проходить в конце занятий.
#
# - На собеседовании нужно объяснить ваше решение ДP и ответить на вопросы по теории.
#
# - Пример вычисления оценки за курс:

# %%
# общее число домашних работ в курсе
N = 18

# сумма набранных баллов за домашние работы
X = 0 * 5 + 1 * 5 + 2 * 8 

# оценка за курс
score = int(10 * X / (2 * N) + 0.5)

print(f"Оценка за модуль: {score}")
# Out:
# Оценка за модуль: 6

# %% [markdown]
# #### **GitHub репозиторий курса**
#
# - Репозиторий курса
#
#     https://github.com/alextanch/computer-vision
#
# - Структура репозитория:
#
#     ```bash
#         computer-vision
#             │
#             ├── notebooks                 - ноутбуки занятий
#             │     ├── notebook_01.ipynb
#             │     ├── notebook_02.ipynb
#             │     ├──...
#             │
#             ├── homeworks                 - домашние работы
#             │     ├── homework_01.ipynb
#             │     ├── homework_02.ipynb
#             │     ├──...
#             │
#             └── src                       - python скрипты
#     ```
#
# - Для запуска ноутбуков и домашних работ в Google Colab:
#     - скопируйте `computer-vision/*` в
#
#       https://drive.google.com/drive/my-drive/computer-vision
#
#     - откройте ноутбук и выберете runtime type
#
# - Для локального запуска:
#
#     - в Linux и MacOS, установите окружение:
#     ```bash
#         bash setup.sh
#     ```
#
#     - в ноутбуке выберете python kernel:
#     ```bash
#         .venv/bin/python
#     ```
#
# - Зависимости в файле `pyproject.toml` будут добавляться по мере необходимости.

# %% [markdown]
# #### **Выполнение домашних работ:**
#
# Например, для **A**lex **T**anchenko, для **ДР-1**:
#
# - В репозитории курса https://github.com/alextanch/computer-vision создадим ветки:
#
#   -  `at/hw` - эту ветку надо **создать один раз и никогда не удалять**. Она будет использоваться для создания pull requests.
#
#   - `at/hw1` - ветка для ДР-1
#
# - В ветке `at/hw1` в файле `homeworks/homework_01.ipynb` коммитим решение ДР-1
#
# - Создадим **Pull request** с именем **at/hw1** из ветки **at/hw1** в ветку **at/hw**. При создании pull request:
#
#   - добавим **alextanch** в **Reviewers**
#
#   - добавим себя - в **Assignees**
#
#   - в **Labels** выберем **homework**
#
#   - в **Projects** выберем **computer-vision**
#
#   - в **Milestone** выберем **Lesson 3** (soft deadline для ДР-1)
#
# - после **code review**, получим **approve** и 👍
#
# - **после approve и** 👍 в pull request, нажмем **Squash and merge** и удалим ветку **at/hw1**
#
# - получим баллы на собеседовании
#
# - переходим к следующему ДР и повторяем процесс 😳
#
# **Важно!**
#
# - Ноутбуки с ДР должны корректно запускаться как в google colab так и локально.
#
# - Все сообщения коммитов должны иметь префикс **at:**
#
# - Перед коммитом ноутбука всегда делайте **Clear All Outputs**.
#
# - Меняйте статус вашего PR на kanban доске https://github.com/users/alextanch/projects/9/views/2
