# %% [markdown]
# ### **Контактная информация**
#
# - **Александр Танченко**
#
# - Ведущий инженер-программист, Лаборатория интеллектуальных беспилотных систем, НИУ ВШЭ.
#
# - mail: alex.tanch@gmail.com
#
# - telegram: alextanch
#
# - github: alextanch
#
# **Прислать на почту alex.tanch@gmail.com:**
#
# - ФИО
#
# - курс, программа обучения
#
# - telegram username
#
# - github username

# %% [markdown]
# ### **Курс: "Глубокое обучение в задачах компьютерного зрения"**
#
# Курс будет читаться в 3 и 4 модуле.

# %% [markdown]
# #### **Модуль 3**
#
# **10 занятий с 20 января по 24 марта**
#
# **План занятий**
#
# *Архитектуры нейронных сетей:*
#
# 1. Основы PyTorch. Обучение нейронных сетей.
#
# 2. Полносвязные нейронные сети. Методы регуляризации.
# 3. Сверточные нейронные сети. Классические архитектуры.
# 4. Остаточные сети (residual networks). Современные архитектуры.
# 5. Визуальные трансформеры.
#
# *Примеры применения нейронных сетей к задачам компьютерного зрения:*
#
# 6. Обучение с малым количеством примеров (few-shot learning).
#
# 7. Cамообучение (self-supervised learning).
# 8. Классификация изображений.
# 9. Сегментация изображений.
#
# *Последнее занятие модуля:*
#
# 10. Прием домашних заданий. Оценка за модуль.

# %% [markdown]
# #### **Оценка за модуль**
#
# - Баллы начисляются за домашние задания.
#
# - Чтобы сдать ДЗ, необходимо получить **pull request approve** и пройти **собеседование**.
# - За ДЗ, сданное в течении 2-х недель можно получить максимум 2 балла, если сдали после двух недель - 1 балл.
#
# - Собеседования будут проходить в конце занятий.
# - На собеседовании нужно объяснить ваше решение ДЗ и ответить на вопросы по теории.
# - Пример вычисления оценки за модуль:

# %%
# число домашних работ в модуле
N = 9 

# сумма баллов за домашние работы
X = 0 + 1 + 2 + 0 + 1 + 2 + 0 + 1 + 2 

# оценка за модуль
score = int(10 * X / (2 * N) + 0.5)

print(f"Оценка за модуль: {score}")
# Out:
# Оценка за модуль: 5

# %% [markdown]
# #### **GitHub репозиторий курса**
#
# - Репозиторий курса
#
#     https://github.com/alextanch/computer-vision
#
# - Структура репозитория:
#
#     ```bash
#         computer-vision
#             │
#             ├── notebooks                 - ноутбуки занятий
#             │     ├── notebook_01.ipynb
#             │     ├── notebook_02.ipynb
#             │     ├──...
#             │
#             ├── homeworks                 - домашние задания
#             │     ├── homework_01.ipynb
#             │     ├── homework_02.ipynb
#             │     ├──...
#             │
#             └── src                       - python скрипты
#     ```
#
# - Для работы в Google Colab:
#     - скопируйте `computer-vision/homeworks` и `computer-vision/notebooks` в
#
#       https://drive.google.com/drive/my-drive/computer-vision
#
#     - откройте ноутбук и выберете runtime type
#
#     - установите недостающие зависимости, например:
#         ```bash
#             !pip install torchinfo -q
#         ```
#
# - Для локальной работы:
#     - в Linux и MacOS, установите окружение:
#     ```bash
#         bash setup.sh
#     ```
#
#     - в ноутбуке выберете python kernel:
#     ```bash
#         .venv/bin/python
#     ```

# %% [markdown]
# #### **Выполнение домашних заданий:**
#
# Ноутбуки с ДЗ должны корректно запускаться как в google colab так и локально.
#
# - в **computer-vision** репозитории создайте ветку для **ваших сданных ДЗ**
#
#   например, для **P**eter **I**vanov ветка должна называться **pi/hw** (или **ip/hw**)
#
# - для текущего ДЗ, например для **homework_01.ipynb**, создайте ветку **pi/hw01** с реализацией вашего ДЗ
#
#   все ваши сообщенья коммитов должны иметь вид: **"[pi] commit message ..."**
#
# - создайте **pull request** из ветки **pi/hw01** в ветку **pi/hw** с именем **pi/hw01**
#
# - в **pull request** добавьте **alextanch** в **reviewer**
#
# - после **code review**, получите **approve**
#
# - после получения **approve**, в pull request, сделайте **squash and merge** и удалите ветку **pi/hw01**
#
# - получите балл на собеседовании
