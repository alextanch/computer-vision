# %% [markdown]
# <a href="https://colab.research.google.com/github/alextanch/computer-vision/blob/at%2Fdev/notebooks/notebook_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# монтирование google диска и установка
# рабочей дериктории в `computer-vision`

import os

try:
    from google.colab import drive
    colab = True
except ImportError:
    colab = False

if colab:
    drive.mount("/content/drive", force_remount=True)
    os.chdir("drive/MyDrive/computer-vision")
else:
    os.chdir("..")

print(f"working directory: {os.getcwd()}")

# %%
# создание директории для данных

from pathlib import Path

if colab:
    DATA_DIR = Path("/content/sample_data")
else:
    DATA_DIR = Path("./data")

DATA_DIR.mkdir(exist_ok=True)

print(f"DATA_DIR: {DATA_DIR}")

# %%
# установка недостающих пакетов в colab
if colab:
    ! pip install rootutils -q
    ! pip install torchmetrics -q
    ! pip install livelossplot -q
    ! pip install torchinfo -q

# %%
# для импорта локальных модулей
# https://github.com/ashleve/rootutils

import rootutils

rootutils.setup_root(".", indicator="notebooks", pythonpath=True)

# %%
# настройки для matplotlib

import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format="retina"

plt.style.use("seaborn-v0_8-notebook")

# %% [markdown]
# **Фрэймворки для обучения нейнонных сетей:**
#
# - [TensorFlow](https://www.tensorflow.org)
# - [JAX](https://docs.jax.dev)
# - [PyTorch + Torchvision](https://pytorch.org)
#
# **Более высокоуровневые фрэймворки:**
# - [Keras](https://keras.io) - PyTorch, JAX, TensorFlow
# - [Flax](https://flax.readthedocs.io) - JAX
# - [PyTorch Lightning](https://lightning.ai/) - PyTorch
# - [Hugging Face](https://huggingface.co/) - PyTorch, JAX, TensorFlow
#
# Учебник по PyTorch [60-min blitz.](https://docs.pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html)

# %% [markdown]
# Выберем ускоритель для вычислений:

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda:0")

    # что бы все операции на GPU были детерменированными
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
else:
    device = torch.device("cpu")

print(f"device: {device}")

# %% [markdown]
# Установим seed для воспроизводимости результатов обучения моделей:

# %%
def set_seed(seed):
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

seed = 0xABCD

set_seed(seed)

print(f"seed = {seed}")

# %% [markdown]
# #### **Обучение модели линейной регрессии для фильтра Габора**
#
# Обучим модель регресси данных для фильтра Габора:
# $$
#     y = \sin(\phi_0 + 0.06\phi_1 x)\cdot
#     \exp\left[-\frac{(\phi_0 + 0.06\phi_1 x)^2}{32}\right]
# $$
#
# Сгенерируем данные для добавив нормальный шум:
# $$
#     y = y + \varepsilon\,,
#     \qquad
#     \varepsilon \sim N\left(0, \sigma^2\right)
# $$

# %%
# функция, генерирующая данные для фильтра Габора
def gabor_data(
        phi0, phi1, # параметры фильтра
        data_size,  # колличество данных
        sigma       # c.к.o. шума
):
    # вычисление (x, y) по формуле фильтра Габора
    x = torch.linspace(-15, 15, data_size)
    t = phi0 + 0.06 * phi1 * x
    y = torch.sin(t) * torch.exp(-t ** 2 / 32)

    # добавление нормального шума к y
    y = y + sigma * torch.randn(data_size)

    return x, y

# истинные значения параметров фильтра Габора
gt_phi0 = 3.0
gt_phi1 = 15.0

# данные для обучения, валидации и тестирования
data_x, data_y = gabor_data(gt_phi0, gt_phi1, data_size=1000, sigma=0.05)

# графики
fig, ax = plt.subplots(1, 1, layout="constrained", figsize=(6, 3))

ax.scatter(data_x, data_y, s=5, c="blue")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("data");

# %% [markdown]
# Класс для итерации по данным по одному сэмплу (x, y):

# %%
from torch.utils.data import Dataset

class DataSet(Dataset):
    def __init__(self, x, y):
        super().__init__()

        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        x = self.x[index]
        y = self.y[index]

        return x, y

# %% [markdown]
# Протестируем объект класса `DataSet`:

# %%
dataset = DataSet(data_x, data_y)

print(f"dataset size: {len(dataset)}\n")

x, y = dataset[777]

print(f"x = {x} \ny = {y}")

# %% [markdown]
# Разделим `dataset` на датасеты для обучения, валидации и тестирования:

# %%
from torch.utils.data import random_split

train_dataset, valid_dataset, test_dataset = random_split(
    dataset,
    [800, 100, 100]
)

print(f"train_dataset size: {len(train_dataset)}")
print(f"valid_dataset size: {len(valid_dataset)}")
print(f"test_dataset size: {len(test_dataset)}")

# %% [markdown]
# Создадим лоадеры датасетов для обучения и валидации.
#
# Лоадеры позволяют генерировать батчи из датасетов.

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,                 # датасет для лоадера
    batch_size=len(train_dataset), # размер батча данных
    num_workers=0                  # число процессов для формирования батчей
)

valid_loader = DataLoader(
    valid_dataset,
    batch_size=len(valid_dataset),
    num_workers=0
)

print(f"train_loader size: {len(train_loader)}")
print(f"valid_loader size: {len(valid_loader)}")

# %% [markdown]
# Сгенерируем батч данных для обучения:

# %%
# батч содержит все обучающие данные
x, y = next(iter(train_loader))

print(f"x shape: {x.shape}")
print(f"y shape: {y.shape}")

# %% [markdown]
# Нейронная сеть для обучения модели регрессии фильра Габора:

# %%
from torch import nn

class Regression(nn.Module):
    def __init__(self, phi0=0.0, phi1=0.0):
        super().__init__()

        self.phi0 = nn.Parameter(phi0 * torch.ones(1), requires_grad=True)
        self.phi1 = nn.Parameter(phi1 * torch.ones(1), requires_grad=True)

    def forward(self, x):
        t = self.phi0 + 0.06 * self.phi1 * x
        y = torch.sin(t) * torch.exp(-t ** 2 / 32)
        return y

# %% [markdown]
# Протестируем модель сети, выполнив `forward` для случайного тензора:

# %%
# начальные параметры модели
phi0 = 2.0
phi1 = 14.0

# модель нейронной сети
model = Regression(phi0, phi1)

# случайный тензор
x = torch.rand(5)

# вызывается функция model.forward(x)
y_hat = model(x)

print(f"x = {x}")
print(f"y_hat = {y_hat}")

# %% [markdown]
# Выведем информацию о модели:

# %%
import torchinfo

print(torchinfo.summary(model, input_size=x.shape, device="cpu"))

# %% [markdown]
# Mean Squared Error Loss - функция потерь для задачи регрессии:
# $$
#     \mathbf{MSE} = \frac{1}{N}\sum^N_{i=1}\left(y_i-\widehat{y}_i\right)^2
# $$

# %%
loss_fn = nn.MSELoss()

x, y = next(iter(train_loader))
y_hat = model(x)

loss = loss_fn(y_hat, y)

print(f"loss value = {loss}")

# %% [markdown]
# В качестве оптимизатора возьмем SGD:

# %%
learning_rate = 0.1
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# Протестируем работу оптимизатора, обновив с его помощью параметры модели:

# %%
# обнулим все производные перед их вычислениями
optimizer.zero_grad()

# вычисление производных loss функция по параметрам
# c помощью метода обратного распространения ошибки (backpropagation)
# `retain_graph=True` - чтобы производные можно вычислять несколько раз подряд
loss.backward(retain_graph=True)

# обновление параметров модели
optimizer.step()

# выведем параметры модели и их производные
print(f"phi0 = {model.phi0}, grad phi0 = {model.phi0.grad}")
print(f"phi1 = {model.phi0}, grad phi1 = {model.phi0.grad}")

# %% [markdown]
# Обучим и провалидируем модель на нескольких эпохах.
#
# Лучшую модель сохраним в файл для последующего тестирования.

# %%
from livelossplot import PlotLosses

# число эпох обучения
epochs = 3000

# скопируем модель на ускоритель
model = model.to(device)

# лучшее значение функции потерь
best_loss = float("inf")

# для построения графиков во время обучения
plot = PlotLosses(figsize=(12, 3))

# цикл по эпохам
for epoch in range(epochs):
    # эпоха обучения модели

    # модель переведем в режим обучения
    model.train()

    # значения loss функции на батчах одной эпохи
    batch_losses = torch.empty(0)

    # выбираем случайные батчи из обучающих данных
    for x, y in train_loader:
        # скопируем батч на ускоритель
        x = x.float().to(device)
        y = y.float().to(device)

        # предсказание модели
        y_hat = model(x)

        # вычисление loss функции по предсказанию `y_hat` и реальному `y`
        loss = loss_fn(y_hat, y)

        # обновление параметров модели
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # удалим loss из вычислительного графа
        # и скопируем его на cpu
        loss = loss.detach().cpu()

        # добавим текущий loss к значениям loss функция на батчах
        batch_losses = torch.concatenate((batch_losses, loss[None]))

    # усреднив, получим среднее значение loss функции в текущей эпохе
    # на обучающих данных
    train_epoch_loss = batch_losses.mean()

    # эпоха валидации модели

    # модель переведем в режим валидации
    model.eval()

    # значения loss функции на батчах одной эпохи
    batch_losses = torch.empty(0)

    # выбираем батчи из данных для валидации
    for x, y in valid_loader:
        # скопируем батч на ускоритель
        x = x.float().to(device)
        y = y.float().to(device)

        # предсказание модели в режиме валидации без использования производных
        with torch.no_grad():
            y_hat = model(x)

        # вычисление loss функции на текущем батче
        loss = loss_fn(y_hat, y)

        # добавим текущий loss к значениям loss функция на батчах
        loss = loss.cpu()
        batch_losses = torch.concatenate((batch_losses, loss[None]))

    # среднее значение loss функции в текущей эпохе
    # на валидационных данных
    valid_epoch_loss = batch_losses.mean()

    # сохраняем модель, если на текущей эпохе получили лучший loss на валидации
    if valid_epoch_loss < best_loss:
        best_loss = valid_epoch_loss
        torch.save(model.state_dict(), DATA_DIR / "regression.pth")

    # строим графики во время обучения
    plot.update({
        "loss": train_epoch_loss,
        "val_loss": valid_epoch_loss
    })

    if epoch % 100 == 0:
        plot.send()

# %% [markdown]
# Загрузим веса обученной модели для тестирования:

# %%
state_dict = torch.load(DATA_DIR / "regression.pth", weights_only=True)

model = Regression()
model.load_state_dict(state_dict, strict=True)

for name, param in model.named_parameters():
    print(f"Обученное {name} = {param.item()}")

print()

print(f"Реальное phi0 = {gt_phi0}")
print(f"Реальное phi1 = {gt_phi1}")

# %% [markdown]
# Протестируем модель на тестовых данных:

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=len(test_dataset),
    num_workers=0
)

# батч содержит все тестовые данные
x, y = next(iter(test_loader))

# модель в режим тестирования
model.eval()

# при тестировании, для скорости
# рекоммендуют использовать `torch.inference_mode()` контекст
with torch.inference_mode():
    y_hat = model(x)

# loss на всех тестовых данных
test_loss = loss_fn(y_hat, y.float())

print(f"Test Loss: {test_loss.item()}")

# график тестовых данных и результатов предсказаний обученной модели
plt.figure(figsize=(8, 3))
plt.scatter(x, y, s=20, c="blue")
plt.scatter(x, y_hat, s=20, c="red")
plt.xlabel("x")
plt.ylabel("y");

# %% [markdown]
# #### **Классификация изображений**

# %%
from src.utils import download_and_extract

download_and_extract("1KpBql_Rpc1dtBSwFTT7UZdNLUoDde6YQ", "fashion-mnist.zip", DATA_DIR)

classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

# %%
from pathlib import Path
from torchvision import io

class DataSet(Dataset):
    def __init__(self, data_dir):
        super().__init__()

        self.files = list(Path(data_dir).glob("**/*.png"))
        self.labels = [int(f.parent.name) for f in self.files]

    def __len__(self):
        return len(self.files)

    def __getitem__(self, index):
        image = io.read_image(self.files[index])

        x = image / 255.0
        y = self.labels[index]

        return x, y

# %%
dataset = DataSet(DATA_DIR / "fashion-mnist/train")
test_dataset = DataSet(DATA_DIR / "fashion-mnist/test")

print(f"dataset size: {len(dataset)}")
print(f"test_dataset size: {len(test_dataset)}")

# %%
import numpy as np

x, y = dataset[123]

print(f"x shape: {x.shape}")
print(f"y: {y}")

image = (255 * x.squeeze()).numpy().astype(np.uint8)

plt.figure(figsize=(3, 3))
plt.imshow(image, cmap="gray")
plt.title(f"class: {classes[y]}")
plt.axis("off");

# %%
train_dataset, valid_dataset = random_split(
    dataset,
    [50_000, 10_000]
)

print(f"train_dataset size: {len(train_dataset)}")
print(f"valid_dataset size: {len(valid_dataset)}")

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=512,
    num_workers=0, #os.cpu_count(),
    shuffle=True,
    drop_last=True
)

valid_loader = DataLoader(
    valid_dataset,
    batch_size=1024,
    num_workers=0, #os.cpu_count(),
    shuffle=False,
    drop_last=False
)

print(f"train_loader size: {len(train_loader)}")
print(f"valid_loader size: {len(valid_loader)}")

# %%
x, y = next(iter(train_loader))

print(f"train x shape: {x.shape}")
print(f"train y shape: {y.shape}\n")

x, y = next(iter(valid_loader))

print(f"valid x shape: {x.shape}")
print(f"valid y shape: {y.shape}")

# %%
class Classication(nn.Module):
    def __init__(self):
        super().__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(in_features = 28 * 28, out_features = 28 * 28 // 4),
            nn.ReLU()
        )

        self.layer2 = nn.Linear(in_features = 28 * 28 // 4, out_features=10)

    def forward(self, x):
        # converting images in to [batch_size, 28 * 28] dimension
        x = x.view(-1, 28 * 28)
        x = self.layer1(x)
        y = self.layer2(x)

        return y

# %%
model = Classication()

y_hat = model(x)

print(f"y_hat shape: {y_hat.shape}")

# %%
import torchinfo

print(torchinfo.summary(model, input_size=x.shape, device="cpu"))

# %%
loss_fn = nn.CrossEntropyLoss()

x, y = next(iter(train_loader))
y_hat = model(x)

loss = loss_fn(y_hat, y)

print(f"loss value = {loss}")

# %%
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# %%
from torchmetrics.classification import MulticlassAccuracy

metric = MulticlassAccuracy(num_classes=10, average=None)

iterator = iter(valid_loader)

x, y = next(iterator)
y_hat = model(x)
metric.update(y_hat, y)

x, y = next(iterator)
y_hat = model(x)
metric.update(y_hat, y)

accuracy = metric.compute()

print(f"class accuracy: {accuracy}")
print(f"mean accuracy: {accuracy.mean()}")

# %%
accuracy.mean()

# %% [markdown]
# #### **Бинарная классификация изображений**

# %%
from torchvision.datasets import MNIST
import torchvision.transforms as T

dataset = MNIST(
    root=DATA_DIR,
    train=True,
    download=True,
    transform=T.Compose([T.ToTensor()])
)

test_dataset = MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.Compose([T.ToTensor()])
)

print(f"Dataset size = {len(dataset)}")
print(f"Test dataset size = {len(test_dataset)}")

# %%
image_tensor, target = dataset[0]

print(f"image_tensor shape = {image_tensor.shape}")
print(f"target = {target}")

image_numpy = image_tensor.squeeze().numpy()

plt.figure(figsize=(3, 3))
plt.imshow(image_numpy, cmap="gray")
plt.title(f"target: {target}")
plt.axis("off");

# %%
dataset = MNIST(
    root=DATA_DIR,
    train=True,
    download=True,
    transform=T.Compose([T.ToTensor()]),
    target_transform=lambda x: x % 2
)

test_dataset = MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.Compose([T.ToTensor()]),
    target_transform=lambda x: x % 2
)

# %%
image_tensor, target = dataset[0]

print(f"image_tensor shape = {image_tensor.shape}")
print(f"target = {target}")

image_numpy = image_tensor.squeeze().numpy()

plt.figure(figsize=(3, 3))
plt.imshow(image_numpy, cmap="gray")
plt.title(f"target: {target}")
plt.axis("off");

# %%
import os

@dataclass
class Config:
    train_size = 40_000
    val_size = 20_000
    batch_size = 512
    num_workers = os.cpu_count()

cfg = Config()

train_dataset, val_dataset = random_split(
    dataset,
    [cfg.train_size, cfg.val_size]
)

train_loader = DataLoader(
    train_dataset,
    batch_size=cfg.batch_size,
    shuffle=True,
    num_workers=cfg.num_workers,
    drop_last=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=cfg.batch_size,
    shuffle=False,
    num_workers=cfg.num_workers,
    drop_last=False
)

print(f"train_loader num batches = {len(train_loader)}")
print(f"val_loader num batches = {len(val_loader)}")

# %%
images, targets = next(iter(train_loader))

print(f"images shape: {images.shape}")
print(f"targets shape: {targets.shape}")

# %%
class BinaryClassicatorNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(in_features = 28 * 28, out_features = 28 * 28 // 4),
            nn.ReLU()
        )

        self.layer2 = nn.Sequential(
            nn.Linear(in_features = 28 * 28 // 4, out_features=1),
            nn.ReLU(),
        )

    def forward(self, x):
        # converting images in to [batch_size, H*W] dimension
        x = x.view(-1, 28 * 28)
        x = self.layer1(x)
        x = self.layer2(x)

        return x

model = BinaryClassicatorNet()

logits = model(images)

print(f"images shape: {images.shape}")
print(f"logits shape: {logits.shape}")

# %%
import torchinfo

print(torchinfo.summary(model, input_size=images.shape))

# %%
from torchmetrics.classification import BinaryAccuracy
from torchmetrics.aggregation import MeanMetric

cfg.epochs = 100
cfg.learning_rate = 0.05

model = model.to(device)

optimizer = torch.optim.SGD(model.parameters(), lr=cfg.learning_rate)

loss_fn = nn.BCEWithLogitsLoss()
plotlosses = PlotLosses(figsize=(12, 3))

best_metric = 0

for epoch in range(cfg.epochs):
    # training
    model.train()
    batch_losses = torch.empty(0)

    metric = BinaryAccuracy()
    mean_loss = MeanMetric()

    for images, targets in train_loader:
        images = images.to(device)
        targets = targets.unsqueeze(1).float().to(device)

        logits = model(images)
        loss = loss_fn(logits, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        mean_loss.update(loss.detach().cpu())
        metric.update(logits.detach().cpu(), targets.cpu())

    train_epoch_loss = mean_loss.compute()
    train_epoch_metric = metric.compute()

    # validation
    model.eval()

    mean_loss = MeanMetric()
    metric = BinaryAccuracy()

    for images, targets in val_loader:
        images = images.to(device)
        targets = targets.unsqueeze(1).float().to(device)

        with torch.no_grad():
            logits = model(images)

        loss = loss_fn(logits, targets)

        mean_loss.update(loss.cpu())
        metric.update(logits.cpu(), targets.cpu())

    val_epoch_loss = mean_loss.compute()
    val_epoch_metric = metric.compute()

    if best_metric < val_epoch_metric:
        best_metric = val_epoch_metric
        torch.save(model.state_dict(), DATA_DIR / "mnist_binary_classificator.pth")

    plotlosses.update({
        "loss": train_epoch_loss,
        "val_loss": val_epoch_loss,
        "accuracy": train_epoch_metric,
        "val_accuracy": val_epoch_metric
    })

    plotlosses.send()

# %%
test_loader = DataLoader(
    test_dataset,
    batch_size=cfg.batch_size,
    shuffle=False,
    drop_last=False,
    num_workers=0
)

state_dict = torch.load(DATA_DIR / "mnist_binary_classificator.pth", weights_only=True)

model = BinaryClassicatorNet()
model.load_state_dict(state_dict, strict=True)

model = model.to(device)
model.eval()

metric = BinaryAccuracy()

for images, targets in test_loader:
    images = images.to(device)
    targets = targets.unsqueeze(1).float().to(device)

    with torch.inference_mode():
        logits = model(images)

    metric.update(logits.cpu(), targets.cpu())

test_acc = metric.compute().item()
print(f"Test accuracy: {100 * test_acc:.2f} %")

# %%
image, target = test_dataset[102]
image_numpy = image.squeeze().numpy()

plt.figure(figsize=(3, 3))
plt.imshow(image_numpy, cmap="gray")
plt.title(f"target: {target}")
plt.axis("off");

# %%
with torch.inference_mode():
    logit = model(image.unsqueeze(0).to(device))

prob = torch.sigmoid(logit[0])
prediction = 1 if prob > 0.5 else 0

print(f"prediction: {prediction}")
